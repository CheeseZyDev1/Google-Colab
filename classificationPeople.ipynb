# %% [markdown]
# <a href="https://colab.research.google.com/github/CheeseZyDev1/Google-Colab/blob/main/classificationPeople.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import load_img
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random

# %%
import os  #case connect via OS
os.chdir("/content/gdrive/")
os.getcwd()
# Out:
# '/content/gdrive'

# %%
from google.colab import drive #case mounted gdrive
drive.mount('/content/gdrive', force_remount=False)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
path = "/content/gdrive/MyDrive/Colab Notebooks/Data set/ClassificationPeople"
files = os.listdir(path)
print(os.listdir(path))
# Out:
# ['Gerard Way', 'Oilver', 'Gerard_new', '.ipynb_checkpoints', 'Oilver_new']

# %%
categories1= []
filename_Gerard = os.listdir(path+"/Gerard Way")
for filename in filename_Gerard:
        categories1.append(0)
df1 = pd.DataFrame({
    'filename': filename_Gerard,
    'category': categories1
})
categories2= []
filename_Oilver = os.listdir(path+"/Oilver")
for filename in filename_Oilver:
        categories2.append(1)

df2 = pd.DataFrame({
    'filename': filename_Oilver,
    'category': categories2
})

# %%
from PIL import Image
def resize():
  for item in filename_Gerard:
    if os.path.isfile(path+'/Gerard Way/'+item):
      im = Image.open(path+'/Gerard Way/'+item)
      f, e = os.path.splitext(path+'/Gerard Way/'+item)
      imResize = im.resize((200,200), Image.ANTIALIAS)
      if imResize != 'RGB':
          imResize = imResize.convert('RGB')
      imResize.save(path + '/Gerard_new/'+ item ,'JPEG',qulity=90)
      print(imResize.size)
resize()
# Out:
# (200, 200)
# <ipython-input-6-426f6857c074>:7: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   imResize = im.resize((200,200), Image.ANTIALIAS)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)

# %%
def resize1():
  for item in filename_Oilver:
    if os.path.isfile(path+'/Oilver/'+item):
      im = Image.open(path+'/Oilver/'+item)
      f, e = os.path.splitext(path+'/Oilver/'+item)
      imResize = im.resize((200,200), Image.ANTIALIAS)
      if imResize != 'RGB':
          imResize = imResize.convert('RGB')
      imResize.save(path + '/Oilver_new/'+ item ,'JPEG',qulity=90)
      print(imResize.size)
resize1()
# Out:
# <ipython-input-7-d05823cad1e1>:6: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   imResize = im.resize((200,200), Image.ANTIALIAS)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)
# (200, 200)

# %%
df2.head(10)
# Out:
#                                             filename  category
# 0  2014-06-05_Vainsteam_Bring_me_the_Horizon_Oli_...         1
# 1        NINTCHDBPICT000461481207-e1548366918817.jpg         1
# 2  Bring_Me_The_Horizont_-_Southside_Festival_202...         1
# 3                            EQUATE-3-COVERS-OLI.jpg         1
# 4                                FKGKPlYWUAAxedi.jpg         1
# 5  Bring_me_the_Horizon_-_2019159204956_2019-06-0...         1
# 6  TELEMMGLPICT000306868830_trans_NvBQzQNjv4BqR1g...         1
# 7      Oli-Sykes-Drop-Dead-Clothing-2022-promo-2.jpg         1
# 8                                             OS.jpg         1
# 9  oli-sykes-bring-me-the-horizon-2018-C-Brandon-...         1

# %%
sample = random.choice(filename_Oilver)
image = load_img(path+"/Oilver_new/"+sample)
plt.imshow(image)

# %%
pip install keras
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (2.13.1)

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.13.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.57.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.13.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.33.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.41.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow) (3.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow) (2.3.7)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow) (3.2.2)

# %%
from tensorflow.keras.utils import load_img
from tensorflow.keras.utils import img_to_array

# %%
X =  np.empty([0])
y = np.empty([0])
filename_Gerard = os.listdir(path+"/Gerard_new")
filename_Oilver = os.listdir(path+"/Oilver_new")
for filename in filename_Gerard:
    print(path+"/Gerard_new/"+filename)
    # load the image
    img = load_img(path+"/Gerard_new/"+filename)

    #print(type(img))
    #print(img.format)
    #print(img.mode)
    print(img.size)
    img.show()


     # convert to numpy array
    img_array = img_to_array(img)

    X = np.append (X,img_array)
    category = filename.split('.')[0]
    y = np.append(y,[0])

for filename in filename_Oilver:
    print(path+"/Oilver_new/"+filename)
    # load the image
    img = load_img(path+"/Oilver_new/"+filename)

    #print(type(img))
    #print(img.format)
    #print(img.mode)
    print(img.size)
    img.show()


     # convert to numpy array
    img_array = img_to_array(img)

    X = np.append (X,img_array)
    category = filename.split('.')[0]
    y = np.append(y,[1])
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/Data set/ClassificationPeople/Gerard_new/gerard-way.jpg
# (200, 200)
# /content/gdrive/MyDrive/Colab Notebooks/Data set/ClassificationPeople/Gerard_new/Gerard-Way-netflix-the-umbrella-academy-2019-billboard-1548.jpg
# (200, 200)
# /content/gdrive/MyDrive/Colab Notebooks/Data set/ClassificationPeople/Gerard_new/Gerard-Way-blonde.jpg
# (200, 200)
# /content/gdrive/MyDrive/Colab Notebooks/Data set/ClassificationPeople/Gerard_new/gerard-way-new-song.jpg
# (200, 200)
# /content/gdrive/MyDrive/Colab Notebooks/Data set/ClassificationPeople/Gerard_new/gerard-way-went-back-to-mcr-roots-making-netflix-------20190219201730559-data.png
# (200, 200)
# /content/gdrive/MyDrive/Colab Notebooks/Data set/ClassificationPeople/Gerard_new/13304342_web1_AP17139111528188.jpg
# (200, 200)
# /content/gdrive/MyDrive/Colab Notebooks/Data set/ClassificationPeople/Gerard_new/MV5BYmE2MDMxZWQtMzM1ZC00Y2U5LWFmNjUtNjQwMDdmNGY2OGVlXkEyXkFqcGdeQXVyNTI5NjIyMw@@._V1_.jpg
# (200, 200)
# /content/gdrive/MyDrive/Colab Notebooks/Data set/ClassificationPeople/Gerard_new/8425179-JECCPRTK-7.jpg
# (200, 200)
# /content/gdrive/MyDrive/Colab Notebooks/Data set/ClassificationPeople/Gerard_new/Gerard-Way-July-2020-promo.jpg
# (200, 200)
# /content/gdrive/MyDrive/Colab Notebooks/Data set/ClassificationPeople/Gerard_new/Screen-Shot-2019-03-21-at-12.27.04-PM.jpg
# (200, 200)
# /content/gdrive/MyDrive/Colab Notebooks/Data set/ClassificationPeople/Gerard_new/mcr3.jpg
# (200, 200)
# /content/gdrive/MyDrive/Colab Notebooks/Data set/ClassificationPeople/Gerard_new/1e8387f2032faf5af52b768786b8ef2f.jpg
# (200, 200)
# /content/gdrive/MyDrive/Colab Notebooks/Data set/ClassificationPeople/Gerard_new/c229693f545915ac8dc821aca0838a36.jpg
# (200, 200)
# /content/gdrive/MyDrive/Colab Notebooks/Data set/ClassificationPeople/Gerard_new/2014MyChemicalRomance01_020614.jpg
# (200, 200)
# /content/gdrive/MyDrive/Colab Notebooks/Data set/ClassificationPeople/Oilver_new/2014-06-05_Vainsteam_Bring_me_the_Horizon_Oli_Sykes_10.jpg
# (200, 200)
# /content/gdrive/MyDrive/Colab Notebooks/Data set/ClassificationPeople/Oilver_new/NINTCHDBPICT000461481207-e1548366918817.jpg
# (200, 200)
# /content/gdrive/MyDrive/Colab Notebooks/Data set/ClassificationPeople/Oilver_new/Bring_Me_The_Horizont_-_Southside_Festival_2022_-_IMG_4429_-_1_(Cropped).jpg
# (200, 200)
# /content/gdrive/MyDrive/Colab Notebooks/Data set/ClassificationPeople/Oilver_new/EQUATE-3-COVERS-OLI.jpg
# (200, 200)
# /content/gdrive/MyDrive/Colab Notebooks/Data set/ClassificationPeople/Oilver_new/FKGKPlYWUAAxedi.jpg
# (200, 200)
# /content/gdrive/MyDrive/Colab Notebooks/Data set/ClassificationPeople/Oilver_new/Bring_me_the_Horizon_-_2019159204956_2019-06-08_Rock_am_Ring_-_1921_-_AK8I9820.jpg
# (200, 200)
# /content/gdrive/MyDrive/Colab Notebooks/Data set/ClassificationPeople/Oilver_new/TELEMMGLPICT000306868830_trans_NvBQzQNjv4BqR1gN756bgu-Oq1JkfYLunP4Xpit_DMGvdp2n7FDd82k.jpeg
# (200, 200)
# /content/gdrive/MyDrive/Colab Notebooks/Data set/ClassificationPeople/Oilver_new/Oli-Sykes-Drop-Dead-Clothing-2022-promo-2.jpg
# (200, 200)
# /content/gdrive/MyDrive/Colab Notebooks/Data set/ClassificationPeople/Oilver_new/OS.jpg
# (200, 200)
# /content/gdrive/MyDrive/Colab Notebooks/Data set/ClassificationPeople/Oilver_new/oli-sykes-bring-me-the-horizon-2018-C-Brandon-Getty-Images.jpg
# (200, 200)
# /content/gdrive/MyDrive/Colab Notebooks/Data set/ClassificationPeople/Oilver_new/bmth1.jpg
# (200, 200)

# %%
X = X.reshape(len(y),200,200,3)
x_vector = 200*200*3

# %%
print(X.shape)
print(y.shape)
print(type(X))
print(type(y))
# Out:
# (25, 200, 200, 3)
# (25,)
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
X_train, X_test, y_train, y_test = train_test_split(
            X, y, test_size=0.2, random_state=1000)
print("X_train shape", X_train.shape)
print("y_train shape", y_train.shape)
print("X_test shape", X_test.shape)
print("y_test shape", y_test.shape)

print(type(X_train))
print(type(y_train))

len_train  = len(X_train)
len_test = len(X_test)
# Out:
# X_train shape (20, 200, 200, 3)
# y_train shape (20,)
# X_test shape (5, 200, 200, 3)
# y_test shape (5,)
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
X_train /= 255
X_test /= 255

print("X_train shape", X_train.shape)
print("y_train shape", y_train.shape)
print("X_test shape", X_test.shape)
print("y_test shape", y_test.shape)
# Out:
# X_train shape (20, 200, 200, 3)
# y_train shape (20,)
# X_test shape (5, 200, 200, 3)
# y_test shape (5,)

# %%
X_train[1]
# Out:
# array([[[0.00784314, 0.00784314, 0.00784314],
#         [0.01176471, 0.01176471, 0.01176471],
#         [0.01568627, 0.01568627, 0.01568627],
#         ...,
#         [0.00784314, 0.00784314, 0.00784314],
#         [0.00784314, 0.00784314, 0.00784314],
#         [0.00784314, 0.00784314, 0.00784314]],
#
#        [[0.01568627, 0.01568627, 0.01568627],
#         [0.00784314, 0.00784314, 0.00784314],
#         [0.02745098, 0.02745098, 0.02745098],
#         ...,
#         [0.00784314, 0.00784314, 0.00784314],
#         [0.00784314, 0.00784314, 0.00784314],
#         [0.00784314, 0.00784314, 0.00784314]],
#
#        [[0.02745098, 0.02745098, 0.02745098],
#         [0.00392157, 0.00392157, 0.00392157],
#         [0.04313725, 0.04313725, 0.04313725],
#         ...,
#         [0.00784314, 0.00784314, 0.00784314],
#         [0.00784314, 0.00784314, 0.00784314],
#         [0.00784314, 0.00784314, 0.00784314]],
#
#        ...,
#
#        [[0.        , 0.        , 0.        ],
#         [0.00392157, 0.00392157, 0.00392157],
#         [0.01176471, 0.01176471, 0.01176471],
#         ...,
#         [0.58823529, 0.60392157, 0.64705882],
#         [0.58431373, 0.6       , 0.64313725],
#         [0.58039216, 0.59607843, 0.63921569]],
#
#        [[0.        , 0.        , 0.        ],
#         [0.00392157, 0.00392157, 0.00392157],
#         [0.01176471, 0.01176471, 0.01176471],
#         ...,
#         [0.58823529, 0.60392157, 0.64705882],
#         [0.58431373, 0.6       , 0.64313725],
#         [0.58039216, 0.59607843, 0.63921569]],
#
#        [[0.        , 0.        , 0.        ],
#         [0.00392157, 0.00392157, 0.00392157],
#         [0.01176471, 0.01176471, 0.01176471],
#         ...,
#         [0.58823529, 0.60392157, 0.64705882],
#         [0.58431373, 0.6       , 0.64313725],
#         [0.58039216, 0.59607843, 0.63921569]]])

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Flatten, Conv2D, Dropout, MaxPooling2D

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Build the CNN model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(200, 200, 3)),
    MaxPooling2D(2, 2),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),  # Add dropout for regularization
    Dense(1, activation='sigmoid')
])

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Build the model explicitly
model.build(input_shape=(None, 200, 200, 3))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 198, 198, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 99, 99, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 97, 97, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 48, 48, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 46, 46, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 23, 23, 128)       0
#  g2D)
#
#  flatten (Flatten)           (None, 67712)             0
#
#  dense (Dense)               (None, 128)               8667264
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 8760641 (33.42 MB)
# Trainable params: 8760641 (33.42 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, batch_size=32, epochs=10,validation_data = (X_test,y_test),callbacks =None)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 2s 2s/step - loss: 0.7195 - accuracy: 0.5500 - val_loss: 0.7934 - val_accuracy: 0.2000
# Epoch 2/10
# 1/1 [==============================] - 1s 1s/step - loss: 1.0037 - accuracy: 0.6500 - val_loss: 1.4628 - val_accuracy: 0.6000
# Epoch 3/10
# 1/1 [==============================] - 1s 1s/step - loss: 1.5747 - accuracy: 0.5500 - val_loss: 0.7873 - val_accuracy: 0.6000
# Epoch 4/10
# 1/1 [==============================] - 1s 1s/step - loss: 0.7312 - accuracy: 0.5500 - val_loss: 0.7198 - val_accuracy: 0.2000
# Epoch 5/10
# 1/1 [==============================] - 2s 2s/step - loss: 0.4455 - accuracy: 0.9000 - val_loss: 0.7339 - val_accuracy: 0.4000
# Epoch 6/10
# 1/1 [==============================] - 2s 2s/step - loss: 0.4909 - accuracy: 0.8000 - val_loss: 0.6855 - val_accuracy: 0.6000
# Epoch 7/10
# 1/1 [==============================] - 1s 1s/step - loss: 0.3848 - accuracy: 0.9500 - val_loss: 0.7176 - val_accuracy: 0.6000
# Epoch 8/10
# 1/1 [==============================] - 1s 984ms/step - loss: 0.3279 - accuracy: 0.9500 - val_loss: 0.8184 - val_accuracy: 0.2000
# Epoch 9/10
# 1/1 [==============================] - 1s 985ms/step - loss: 0.2598 - accuracy: 0.9000 - val_loss: 0.8774 - val_accuracy: 0.6000
# Epoch 10/10
# 1/1 [==============================] - 1s 967ms/step - loss: 0.1655 - accuracy: 1.0000 - val_loss: 1.0772 - val_accuracy: 0.6000

# %%
print(history.history.keys())
plt.figure(figsize=(9,6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','test'],loc = 'upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
test_loss, test_accuracy = model.evaluate(X_test,  y_test, verbose=2)

print('\nTest accuracy:', test_accuracy)
# Out:
# 1/1 - 0s - loss: 1.0772 - accuracy: 0.6000 - 74ms/epoch - 74ms/step
#
# Test accuracy: 0.6000000238418579

# %%
class_names = ['Gerard Way', 'Oilver']

# %%
from sklearn.metrics import classification_report
prediction = model.predict(X_test)
predicted_class = (prediction> 0.5).astype("int32")
print(classification_report(y_test, predicted_class, target_names=class_names))
# Out:
# 1/1 [==============================] - 0s 141ms/step
#               precision    recall  f1-score   support
#
#   Gerard Way       0.60      1.00      0.75         3
#       Oilver       0.00      0.00      0.00         2
#
#     accuracy                           0.60         5
#    macro avg       0.30      0.50      0.37         5
# weighted avg       0.36      0.60      0.45         5
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_test, predicted_class)
# Out:
# array([[3, 0],
#        [2, 0]])

# %%
from keras.optimizers import SGD
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(200, 200, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
model.add(Dense(1, activation='sigmoid'))
 # compile model
opt = SGD(lr=0.001, momentum=0.9)
model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 200, 200, 32)      896
#
#  max_pooling2d_3 (MaxPoolin  (None, 100, 100, 32)      0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 100, 100, 64)      18496
#
#  max_pooling2d_4 (MaxPoolin  (None, 50, 50, 64)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 50, 50, 128)       73856
#
#  max_pooling2d_5 (MaxPoolin  (None, 25, 25, 128)       0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 80000)             0
#
#  dense_2 (Dense)             (None, 128)               10240128
#
#  dense_3 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 10333505 (39.42 MB)
# Trainable params: 10333505 (39.42 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, batch_size=32, epochs=30,validation_data = (X_test,y_test),callbacks =None)
# Out:
# Epoch 1/30
# 1/1 [==============================] - 2s 2s/step - loss: 0.9074 - accuracy: 0.3000 - val_loss: 5.9628 - val_accuracy: 0.6000
# Epoch 2/30
# 1/1 [==============================] - 2s 2s/step - loss: 6.1016 - accuracy: 0.5500 - val_loss: 5.1072 - val_accuracy: 0.4000
# Epoch 3/30
# 1/1 [==============================] - 1s 1s/step - loss: 5.5138 - accuracy: 0.4500 - val_loss: 1.0675 - val_accuracy: 0.4000
# Epoch 4/30
# 1/1 [==============================] - 1s 1s/step - loss: 0.8401 - accuracy: 0.4500 - val_loss: 0.7309 - val_accuracy: 0.6000
# Epoch 5/30
# 1/1 [==============================] - 1s 1s/step - loss: 0.6402 - accuracy: 0.6500 - val_loss: 0.7268 - val_accuracy: 0.6000
# Epoch 6/30
# 1/1 [==============================] - 1s 1s/step - loss: 0.6786 - accuracy: 0.5500 - val_loss: 0.7356 - val_accuracy: 0.6000
# Epoch 7/30
# 1/1 [==============================] - 1s 1s/step - loss: 0.6249 - accuracy: 0.6000 - val_loss: 0.7622 - val_accuracy: 0.4000
# Epoch 8/30
# 1/1 [==============================] - 1s 1s/step - loss: 0.5843 - accuracy: 0.7000 - val_loss: 0.7752 - val_accuracy: 0.4000
# Epoch 9/30
# 1/1 [==============================] - 1s 1s/step - loss: 0.5182 - accuracy: 0.8000 - val_loss: 0.8256 - val_accuracy: 0.6000
# Epoch 10/30
# 1/1 [==============================] - 1s 1s/step - loss: 0.4696 - accuracy: 0.7500 - val_loss: 0.8420 - val_accuracy: 0.6000
# Epoch 11/30
# 1/1 [==============================] - 1s 1s/step - loss: 0.3859 - accuracy: 0.9000 - val_loss: 0.8697 - val_accuracy: 0.4000
# Epoch 12/30
# 1/1 [==============================] - 1s 1s/step - loss: 0.3534 - accuracy: 0.8500 - val_loss: 0.9328 - val_accuracy: 0.6000
# Epoch 13/30
# 1/1 [==============================] - 2s 2s/step - loss: 0.2658 - accuracy: 1.0000 - val_loss: 1.0732 - val_accuracy: 0.6000
# Epoch 14/30
# 1/1 [==============================] - 1s 1s/step - loss: 0.2377 - accuracy: 0.9500 - val_loss: 1.0443 - val_accuracy: 0.4000
# Epoch 15/30
# 1/1 [==============================] - 1s 1s/step - loss: 0.1678 - accuracy: 1.0000 - val_loss: 1.1164 - val_accuracy: 0.2000
# Epoch 16/30
# 1/1 [==============================] - 1s 1s/step - loss: 0.1311 - accuracy: 1.0000 - val_loss: 1.3442 - val_accuracy: 0.6000
# Epoch 17/30
# 1/1 [==============================] - 1s 1s/step - loss: 0.0959 - accuracy: 1.0000 - val_loss: 1.4311 - val_accuracy: 0.6000
# Epoch 18/30
# 1/1 [==============================] - 1s 1s/step - loss: 0.0605 - accuracy: 1.0000 - val_loss: 1.4171 - val_accuracy: 0.4000
# Epoch 19/30
# 1/1 [==============================] - 1s 1s/step - loss: 0.0419 - accuracy: 1.0000 - val_loss: 1.5373 - val_accuracy: 0.4000
# Epoch 20/30
# 1/1 [==============================] - 1s 1s/step - loss: 0.0281 - accuracy: 1.0000 - val_loss: 1.8009 - val_accuracy: 0.4000
# Epoch 21/30
# 1/1 [==============================] - 1s 1s/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 2.1507 - val_accuracy: 0.6000
# Epoch 22/30
# 1/1 [==============================] - 1s 998ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 2.4170 - val_accuracy: 0.6000
# Epoch 23/30
# 1/1 [==============================] - 1s 1s/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 2.5438 - val_accuracy: 0.6000
# Epoch 24/30
# 1/1 [==============================] - 1s 1s/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 2.6052 - val_accuracy: 0.6000
# Epoch 25/30
# 1/1 [==============================] - 2s 2s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 2.6564 - val_accuracy: 0.4000
# Epoch 26/30
# 1/1 [==============================] - 1s 1s/step - loss: 8.3077e-04 - accuracy: 1.0000 - val_loss: 2.7172 - val_accuracy: 0.4000
# Epoch 27/30
# 1/1 [==============================] - 1s 1s/step - loss: 5.8733e-04 - accuracy: 1.0000 - val_loss: 2.7894 - val_accuracy: 0.4000
# Epoch 28/30
# 1/1 [==============================] - 1s 1s/step - loss: 4.9002e-04 - accuracy: 1.0000 - val_loss: 2.8709 - val_accuracy: 0.4000
# Epoch 29/30
# 1/1 [==============================] - 1s 1s/step - loss: 4.3911e-04 - accuracy: 1.0000 - val_loss: 2.9591 - val_accuracy: 0.4000
# Epoch 30/30
# 1/1 [==============================] - 1s 1s/step - loss: 3.9666e-04 - accuracy: 1.0000 - val_loss: 3.0510 - val_accuracy: 0.4000

# %%
test_loss, test_accuracy = model.evaluate(X_test,  y_test, verbose=2)

print('\nTest accuracy:', test_accuracy)
# Out:
# 1/1 - 0s - loss: 3.0510 - accuracy: 0.4000 - 81ms/epoch - 81ms/step
#
# Test accuracy: 0.4000000059604645

# %%
print(history.history.keys())
plt.figure(figsize=(9,6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','test'],loc = 'upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
modelD = Sequential()
modelD.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(200, 200, 3)))
modelD.add(MaxPooling2D((2, 2)))
modelD.add(Dropout(0.2))
modelD.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
modelD.add(MaxPooling2D((2, 2)))
modelD.add(Dropout(0.2))
modelD.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
modelD.add(MaxPooling2D((2, 2)))
modelD.add(Dropout(0.2))
modelD.add(Flatten())
modelD.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
modelD.add(Dropout(0.5))
modelD.add(Dense(1, activation='sigmoid'))
# compile model
opt = SGD(lr=0.001, momentum=0.9)
modelD.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.

# %%
historyD = modelD.fit(X_train, y_train, batch_size=32, epochs=50,validation_data = (X_test,y_test),callbacks =None)
# Out:
# Epoch 1/50
# 1/1 [==============================] - 2s 2s/step - loss: 1.4217 - accuracy: 0.6000 - val_loss: 21.7636 - val_accuracy: 0.6000
# Epoch 2/50
# 1/1 [==============================] - 2s 2s/step - loss: 60.7523 - accuracy: 0.5500 - val_loss: 0.9217 - val_accuracy: 0.4000
# Epoch 3/50
# 1/1 [==============================] - 1s 1s/step - loss: 1.7619 - accuracy: 0.4000 - val_loss: 0.7355 - val_accuracy: 0.4000
# Epoch 4/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.8628 - accuracy: 0.3500 - val_loss: 0.6915 - val_accuracy: 0.6000
# Epoch 5/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.7099 - accuracy: 0.6000 - val_loss: 0.6826 - val_accuracy: 0.6000
# Epoch 6/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.7950 - accuracy: 0.5500 - val_loss: 0.6891 - val_accuracy: 0.6000
# Epoch 7/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.6792 - accuracy: 0.5500 - val_loss: 0.6938 - val_accuracy: 0.6000
# Epoch 8/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.7170 - accuracy: 0.4000 - val_loss: 0.6970 - val_accuracy: 0.4000
# Epoch 9/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.6961 - accuracy: 0.5500 - val_loss: 0.7007 - val_accuracy: 0.2000
# Epoch 10/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.6518 - accuracy: 0.5500 - val_loss: 0.7021 - val_accuracy: 0.4000
# Epoch 11/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.6487 - accuracy: 0.6000 - val_loss: 0.7027 - val_accuracy: 0.2000
# Epoch 12/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6204 - accuracy: 0.7000 - val_loss: 0.7023 - val_accuracy: 0.4000
# Epoch 13/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.5932 - accuracy: 0.7500 - val_loss: 0.7030 - val_accuracy: 0.6000
# Epoch 14/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.6057 - accuracy: 0.6500 - val_loss: 0.7079 - val_accuracy: 0.6000
# Epoch 15/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.5893 - accuracy: 0.7500 - val_loss: 0.7131 - val_accuracy: 0.6000
# Epoch 16/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.5574 - accuracy: 0.8000 - val_loss: 0.7196 - val_accuracy: 0.6000
# Epoch 17/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.5639 - accuracy: 0.6500 - val_loss: 0.7281 - val_accuracy: 0.6000
# Epoch 18/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.5044 - accuracy: 0.8000 - val_loss: 0.7403 - val_accuracy: 0.6000
# Epoch 19/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.5207 - accuracy: 0.8000 - val_loss: 0.7554 - val_accuracy: 0.6000
# Epoch 20/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.4245 - accuracy: 0.8500 - val_loss: 0.7748 - val_accuracy: 0.6000
# Epoch 21/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.4189 - accuracy: 0.7500 - val_loss: 0.7925 - val_accuracy: 0.6000
# Epoch 22/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.3950 - accuracy: 0.7000 - val_loss: 0.8342 - val_accuracy: 0.6000
# Epoch 23/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.3368 - accuracy: 0.8000 - val_loss: 0.8695 - val_accuracy: 0.6000
# Epoch 24/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.4188 - accuracy: 0.7500 - val_loss: 0.9363 - val_accuracy: 0.6000
# Epoch 25/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.2400 - accuracy: 0.8500 - val_loss: 0.9695 - val_accuracy: 0.6000
# Epoch 26/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.2905 - accuracy: 0.9500 - val_loss: 0.9774 - val_accuracy: 0.6000
# Epoch 27/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.3405 - accuracy: 0.9000 - val_loss: 1.0440 - val_accuracy: 0.4000
# Epoch 28/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.2461 - accuracy: 0.9000 - val_loss: 1.1094 - val_accuracy: 0.4000
# Epoch 29/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.1898 - accuracy: 0.9000 - val_loss: 1.2721 - val_accuracy: 0.6000
# Epoch 30/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.0833 - accuracy: 1.0000 - val_loss: 1.4262 - val_accuracy: 0.6000
# Epoch 31/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.2400 - accuracy: 0.8500 - val_loss: 1.3664 - val_accuracy: 0.6000
# Epoch 32/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.2589 - accuracy: 0.8000 - val_loss: 1.1999 - val_accuracy: 0.2000
# Epoch 33/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.2973 - accuracy: 0.9500 - val_loss: 1.2062 - val_accuracy: 0.6000
# Epoch 34/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2876 - accuracy: 0.8500 - val_loss: 1.1825 - val_accuracy: 0.6000
# Epoch 35/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.0956 - accuracy: 1.0000 - val_loss: 1.2176 - val_accuracy: 0.4000
# Epoch 36/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.1203 - accuracy: 1.0000 - val_loss: 1.3719 - val_accuracy: 0.6000
# Epoch 37/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.1692 - accuracy: 0.9500 - val_loss: 1.4233 - val_accuracy: 0.4000
# Epoch 38/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.1497 - accuracy: 0.9500 - val_loss: 1.4039 - val_accuracy: 0.2000
# Epoch 39/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.1157 - accuracy: 0.9500 - val_loss: 1.4442 - val_accuracy: 0.0000e+00
# Epoch 40/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.1647 - accuracy: 0.9000 - val_loss: 1.5313 - val_accuracy: 0.0000e+00
# Epoch 41/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.1631 - accuracy: 0.9000 - val_loss: 1.7292 - val_accuracy: 0.2000
# Epoch 42/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.0913 - accuracy: 0.9500 - val_loss: 1.9439 - val_accuracy: 0.4000
# Epoch 43/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.0495 - accuracy: 1.0000 - val_loss: 2.1937 - val_accuracy: 0.4000
# Epoch 44/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.0223 - accuracy: 1.0000 - val_loss: 2.4191 - val_accuracy: 0.6000
# Epoch 45/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.2299 - accuracy: 0.9000 - val_loss: 2.0589 - val_accuracy: 0.0000e+00
# Epoch 46/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.1331 - accuracy: 0.9500 - val_loss: 1.8724 - val_accuracy: 0.2000
# Epoch 47/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.1968 - accuracy: 0.9500 - val_loss: 1.7982 - val_accuracy: 0.0000e+00
# Epoch 48/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.4039 - accuracy: 0.9000 - val_loss: 2.1104 - val_accuracy: 0.4000
# Epoch 49/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.0857 - accuracy: 0.9500 - val_loss: 2.8415 - val_accuracy: 0.6000
# Epoch 50/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.1389 - accuracy: 0.9500 - val_loss: 3.0647 - val_accuracy: 0.6000

# %%
pip install visualkeras
# Out:
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (9.4.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.23.5)
# Collecting aggdraw>=1.3.11 (from visualkeras)
#   Downloading aggdraw-1.3.16-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.0/993.0 kB 12.4 MB/s eta 0:00:00
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.16 visualkeras-0.0.2

# %%
import visualkeras

# %%
visualkeras.layered_view(model)
# Out:
# <PIL.Image.Image image mode=RGBA size=797x1067>

# %%
from collections import defaultdict
color_map = defaultdict(dict)
color_map[Conv2D]['fill'] = 'orange'
color_map[MaxPooling2D]['fill'] = 'red'
color_map[Dense]['fill'] = 'pink'
color_map[Flatten]['fill'] = 'blue'
visualkeras.layered_view(model, legend=True,spacing=10, color_map=color_map)
# Out:
# <PIL.Image.Image image mode=RGBA size=797x1103>

# %%
tf.keras.Sequential([model,tf.keras.layers.Softmax()])
result = model.predict(X_test)
for i in range(5):
  print(np.argmax(result[i]))
# Out:
# 1/1 [==============================] - 0s 121ms/step
# 0
# 0
# 0
# 0
# 0

# %%
from tensorflow.keras.utils import array_to_img
image_show = array_to_img(X_test[3].reshape(200,200,3))
image_show
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
print(np.argmax(result[3])) #Gerard Way = 0 , Oilver = 1
resultx = np.argmax(result[3])
if resultx == 0:
  print("Gerard Way")
else:
  print("Oilver")
# Out:
# 0
# Gerard Way

# %%
# load and prepare the image
def load_image(filename):
 # load the image
 img = load_img(filename, target_size=(200, 200))
 # convert to array
 img = img_to_array(img)
 # reshape into a single sample with 3 channels
 img = img.reshape(1, 200, 200, 3)
 # center pixel data
 img = img.astype('float32')
 img /= 255
 #img = img - [123.68, 116.779, 103.939]
 return img

# load an image and predict the class
def run_example():
 # load the image
 img = load_image('/content/sample_data/iioo.png')
 # predict the class
 result = model.predict(img)
 print(result)
 result_class = (result> 0.5).astype("int32")

 if result_class  == 0:
    print("Gerard Way")
 else:
    print("Oilver")

# entry point, run the example
run_example()
# Out:
# 1/1 [==============================] - 0s 108ms/step
# [[0.9997732]]
# Oilver
